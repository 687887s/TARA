# %%
import pandas as pd
import glob

# %%
datas = glob.glob('../data/catalog/ps1/*.csv')
z_phot = pd.read_csv('ps1_estimate_xgb.csv')
z_phot_filtered = pd.read_csv('ps1_estimate_filtered_xgb.csv')

# %%
for target in datas:
    df = pd.read_csv(target)
    df = pd.merge(df, z_phot, left_on='objID', right_on='objID', how='left')
    df[pd.isna(df['z_phot']) == False].to_csv('../data/catalog/ps1/xgb/result' +target.split('../data/catalog/ps1')[1])

# %%
for target in datas:
    df = pd.read_csv(target)
    df = pd.merge(df, z_phot_filtered, left_on='objID', right_on='objID', how='left')
    df[pd.isna(df['z_phot']) == False].to_csv('../data/catalog/ps1/xgb/result_filtered' +target.split('../data/catalog/ps1')[1])

# %%
df[pd.isna(df['z_phot']) == False]
# Out:
#                    objName  objAltName1  objAltName2  objAltName3  \
# 871  PSO J359.6423+00.5691         -999         -999         -999
#
#                   objID    uniquePspsOBid        ippObjID  surveyID  \
# 871  108683596422783317  3593631000028344  83305185701559         0
#
#               htmID  zoneID  ...  yMeanApMagStd  yMeanApMagNpt    yFlags  \
# 871  13194398415559   10868  ...       0.130973             11  16892216
#
#      distance  Unnamed: 0    z_phot      odds      D_L_Mpc  Absolute_Mag_r  \
# 871  0.013087   1346481.0  0.267072  0.871879  1072.314006      -21.560462
#
#      Calculated_Flux
# 871         0.000133
#
# [1 rows x 136 columns]

# %%
datas_matched = glob.glob('../data/catalog/ps1/xgb/result/*.csv')
datas_matched_filtered = glob.glob('../data/catalog/ps1/xgb/result_filtered/*.csv')

# %%
pd.read_csv(datas_matched_filtered[0]).size
# Out:
# 137

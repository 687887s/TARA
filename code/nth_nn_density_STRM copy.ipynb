# %%
from sklearn.neighbors import NearestNeighbors
import glob
import pandas as pd
from astropy.cosmology import Planck18
from astropy import units as u
import numpy as np
from astropy.coordinates import SkyCoord
from scipy.stats import norm
from joblib import Parallel, delayed
import matplotlib.pyplot as plt

# %%
barred_target = pd.read_csv('../data/matched_barred_ps1_resolved.csv')
unbarred_target = pd.read_csv('../data/matched_unbarred_ps1_resolved.csv')

# %%
target = pd.read_csv('../all_sample_20260702.csv')
target = pd.merge(target, barred_target[['paliya_RA', 'class']], how='left', on='paliya_RA')
target = pd.merge(target, unbarred_target[['paliya_RA', 'class']], how='left', on='paliya_RA')
target['class'] = target['class_x'].combine_first(target['class_y'])
target = target.drop(['class_x', 'class_y'], axis=1)

target = target[target['class'].isin(['barred', 'unbarred'])]
tg_z = (target.paliya_Z).values
tg_d = Planck18.comoving_distance(target.paliya_Z).value
tg_ra = (target.paliya_RA).values
tg_dec = (target.paliya_DEC).values

coord = SkyCoord(ra = tg_ra * u.deg, dec = tg_dec * u.deg, distance = tg_d * u.Mpc)
tg_df = pd.DataFrame({'coord':coord})

# %%
from astropy.coordinates import Distance
from astropy.cosmology import z_at_value


def compute_index_for_target(i):
    file_list = glob.glob(f'../data/catalog/ps1/matched/t{tg_ra[i]:08.4f}{tg_dec[i]:+07.4f}.csv')
    if len(file_list) == 0:
        return [-999]*3

    target_z = float(target.paliya_Z.iloc[i])
    df = pd.read_csv(file_list[0])
    # df = df[df.Absolute_Mag_r < -20.5]

    z_window = (
        z_at_value(Planck18.comoving_distance, (tg_d[i] + 5) * u.Mpc)
        - z_at_value(Planck18.comoving_distance, (tg_d[i] - 5) * u.Mpc)
    )
    # df = df[np.isfinite(df.z_phot0) & np.isfinite(df.z_photErr)]
    # df = df[np.abs(df.z_phot0 - target_z) < z_window]

    if len(df) == 0:
        return [-999]*3

    surround_z = df['z_phot0'].to_numpy(dtype=float)
    surround_err = df['z_photErr'].to_numpy(dtype=float)
    surround_ra = df.raMean.to_numpy(dtype=float)
    surround_dec = df.decMean.to_numpy(dtype=float)

    mask = (surround_z - surround_err / 2) > -1
    surround_z = surround_z[mask]
    surround_err = surround_err[mask]
    surround_ra = surround_ra[mask]
    surround_dec = surround_dec[mask]

    if len(surround_z) == 0:
        return [-999]*3

    surround_d = Planck18.comoving_distance(surround_z).value
    valid = np.isfinite(surround_d) & (surround_d >= 0)
    surround_z = surround_z[valid]
    surround_err = surround_err[valid]
    surround_ra = surround_ra[valid]
    surround_dec = surround_dec[valid]
    surround_d = surround_d[valid]

    if len(surround_d) == 0:
        return [-999]*3

    z_low = surround_z - surround_err / 2
    id = np.where(z_low < 0)
    z_low[id] = abs(surround_z[id] - surround_err[id] /2)
    z_low = Planck18.comoving_distance(z_low)
    z_low[id] = z_low[id] * -1
    surround_scale = (
        Planck18.comoving_distance(surround_z + surround_err / 2)
        - z_low
    ).value
    surround_odds = np.abs(
        norm.cdf(Planck18.comoving_distance(tg_z[i] + 1000/300000), loc=surround_d, scale=surround_scale)
        - norm.cdf(Planck18.comoving_distance(tg_z[i] - 1000/300000), loc=surround_d, scale=surround_scale)
    )

    coord_1 = SkyCoord(ra=surround_ra * u.deg, dec=surround_dec * u.deg, distance=surround_d * u.Mpc)
    target_coord = coord[i]

    df_surround = target_coord.separation(coord_1)
    df_surround = df_surround.to_value(u.rad) * tg_d[i]
    X = np.asarray(df_surround, dtype=float).reshape(-1, 1)
    nn = NearestNeighbors(n_neighbors=max(1, min(int(len(X) / 2), len(X))), algorithm='auto')
    nn.fit(X)
    neighbors = nn.kneighbors(np.array([[0]]))
    k_index = np.where(np.cumsum(surround_odds[neighbors[1][0]]) >= 5)[0]
    #calculate the density

    if len(k_index) == 0:
        return [-999]*3
    index = neighbors[1][0][:k_index[0]]
    
    row = df.distance.iloc[index] / 60
    row = np.deg2rad(row)
    fifth_dis = row * tg_d[i]
    fifth_dis = (fifth_dis**2) * surround_odds[index]
    fifth_dens = np.sum(surround_odds[index]) / np.pi / np.sum(fifth_dis)
    fifth_dens = np.log(fifth_dens)

    from mc_density_error import calculate_single_target_5nn_error
    error, error_total = calculate_single_target_5nn_error(tg_z[i], df.z_phot0.iloc[index], df.z_photErr.iloc[index], df.distance.iloc[index], n_mc_realizations = 10000)
    return [fifth_dens, error, error_total]

dens = Parallel(n_jobs=-1, verbose=51)(delayed(compute_index_for_target)(i) for i in range(len(tg_df)))
dens = np.array([[dens[i][0], dens[i][1], dens[i][2], j] for i, j in enumerate(target['class'].values)])
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   22.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   22.4s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   35.4s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   36.1s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   36.7s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   38.5s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   40.4s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   41.8s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   49.9s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   50.8s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   50.9s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   56.1s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   57.3s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   57.8s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   58.0s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   58.8s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   59.2s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   59.4s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 187 out of 202 | elapsed:  2.1min remaining:    9.9s
# [Parallel(n_jobs=-1)]: Done 191 out of 202 | elapsed:  2.1min remaining:    7.2s
# [Parallel(n_jobs=-1)]: Done 195 out of 202 | elapsed:  2.2min remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done 199 out of 202 | elapsed:  2.2min remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 202 out of 202 | elapsed:  2.2min finished

# %%
dens
# Out:
# array([['-1.2182397095451538', '0.020794276644314984',
#         '0.19533484057167144', 'barred'],
#        ['-1.4713256783436583', '0.022637583756848895',
#         '0.1955396588888002', 'barred'],
#        ['-0.8846137816277758', '0.016603731183435146',
#         '0.19493327547961578', 'barred'],
#        ['-1.5665345737008545', '0.01600574046227482',
#         '0.1948832515321563', 'unbarred'],
#        ['-1.3625357160792788', '0.02166205172852832',
#         '0.19542912394290016', 'barred'],
#        ['-1.8752444795811878', '0.01394362919517346',
#         '0.19472473596113177', 'barred'],
#        ['-1.8776864827653246', '0.020124507809617127',
#         '0.19526467631033353', 'unbarred'],
#        ['-1.1804477732464234', '0.020397923528128414',
#         '0.1952930446387156', 'unbarred'],
#        ['-0.9547357509035737', '0.013825459494291379',
#         '0.19471630987215297', 'unbarred'],
#        ['-1.584553647561627', '0.02219093676823617',
#         '0.19548845406993184', 'unbarred'],
#        ['-0.9714795214882143', '0.03212629900013377',
#         '0.19686390498881706', 'unbarred'],
#        ['-0.29099457375493487', '0.03351476007237394',
#         '0.19709524890952795', 'unbarred'],
#        ['-1.356959883183953', '0.0170966788201625', '0.1949758816538081',
#         'barred'],
#        ['-2.1258620394894128', '0.021757089490301473',
#         '0.19543968108623433', 'barred'],
#        ['-0.9382954389555647', '0.016866719597559535',
#         '0.19495585200240256', 'barred'],
#        ['-1.8168358896095638', '0.026199519502476752',
#         '0.1959839606247426', 'barred'],
#        ['-1.7599392997047418', '0.024431529421244613',
#         '0.19575545364015057', 'unbarred'],
#        ['-1.300007294389288', '0.018392918951731965',
#         '0.19509381709209797', 'barred'],
#        ['-1.674491193544616', '0.026134355728354427',
#         '0.19597526004405805', 'unbarred'],
#        ['-2.526181702854189', '0.012348839354922576',
#         '0.19461703890824583', 'unbarred'],
#        ['-1.5926383793801988', '0.02176757019578967',
#         '0.1954408481158139', 'unbarred'],
#        ['-1.3532647523369299', '0.02764887262989693',
#         '0.1961829711205951', 'unbarred'],
#        ['0.7191695911724976', '0.05058803386611446',
#         '0.20070487580135948', 'barred'],
#        ['-2.182614996586391', '0.019709223019906644',
#         '0.19522231294615996', 'barred'],
#        ['-2.0033207273576195', '0.02108657614017289',
#         '0.19536617335996348', 'barred'],
#        ['-1.057450889426399', '0.01760766619109115',
#         '0.19502135244300017', 'barred'],
#        ['-1.1021030924846942', '0.025892482646500268',
#         '0.1959431515965774', 'unbarred'],
#        ['-2.3254722869706113', '0.01874446701391448',
#         '0.19512727396147295', 'unbarred'],
#        ['-1.58209530547691', '0.02382018346443376', '0.1956800938784507',
#         'barred'],
#        ['-1.2534920716981337', '0.021369810235620713',
#         '0.19539694672513805', 'unbarred'],
#        ['-2.028550212303913', '0.03354406635963025',
#         '0.19710023436804755', 'unbarred'],
#        ['-1.6411619029744133', '0.021025680513944357',
#         '0.19535961005559582', 'unbarred'],
#        ['-2.4440935034636064', '0.020559920044459366',
#         '0.19531003126371815', 'barred'],
#        ['-2.6732870768517243', '0.01786394969535068',
#         '0.19504465821631214', 'unbarred'],
#        ['-1.127838871879094', '0.021785088501911017',
#         '0.1954428000235263', 'unbarred'],
#        ['-2.071904964643867', '0.023322773926993542',
#         '0.19562016711895952', 'unbarred'],
#        ['-1.2640021279768108', '0.025753612718854832',
#         '0.19592484928684456', 'barred'],
#        ['-1.3521684020373004', '0.01883244354800698',
#         '0.1951357448802983', 'unbarred'],
#        ['-2.6259936824444394', '0.014697217918109446',
#         '0.19478014840977093', 'barred'],
#        ['-2.0990457480461076', '0.017852070823300904',
#         '0.19504357060072539', 'unbarred'],
#        ['-1.932433700671277', '0.01696779221534093',
#         '0.19496462236175818', 'unbarred'],
#        ['-1.272461993296601', '0.01588831100628411',
#         '0.19487364220600079', 'unbarred'],
#        ['-1.0480749485038305', '0.022515684150067525',
#         '0.1955255840874682', 'barred'],
#        ['-0.4787278194195776', '0.02964406187512289',
#         '0.1964740909241117', 'barred'],
#        ['-2.066133017995635', '0.015146131417089493',
#         '0.19481453564070558', 'barred'],
#        ['-1.9082249209837576', '0.0166235434660193',
#         '0.19493496401971255', 'barred'],
#        ['-1.1596640261275801', '0.027660180719006475',
#         '0.19618456513550728', 'barred'],
#        ['0.14132564092034752', '0.012524219571439817',
#         '0.19462824583259655', 'barred'],
#        ['-0.8329035776330033', '0.026610557926841284',
#         '0.1960393322605894', 'barred'],
#        ['-2.2717955688753326', '0.013168539461603708',
#         '0.19467076933004557', 'unbarred'],
#        ['-1.4499658892505518', '0.02068865163584329',
#         '0.19532362454784952', 'unbarred'],
#        ['-1.5885629965043715', '0.023838894327260305',
#         '0.19568237243744332', 'barred'],
#        ['-0.4457333751123064', '0.02139484826553667',
#         '0.1953996866228432', 'barred'],
#        ['-1.6857235338713994', '0.02751483637427868',
#         '0.1961641257230876', 'barred'],
#        ['-1.572274616805267', '0.02542326496350127',
#         '0.19588170001662836', 'barred'],
#        ['-1.7468551512508308', '0.01718301495316724',
#         '0.19498347110173406', 'unbarred'],
#        ['-0.8787960255752528', '0.026429877034388354',
#         '0.196014888210189', 'barred'],
#        ['-1.9941046200160184', '0.01910553577841039',
#         '0.1951622901520171', 'unbarred'],
#        ['-0.6431553062444583', '0.012632329601470982',
#         '0.19463523255351328', 'barred'],
#        ['-1.9137755752312657', '0.018365036198132186',
#         '0.19509119035609654', 'unbarred'],
#        ['-0.3787419371074061', '0.028845613362748254',
#         '0.19635520724002498', 'unbarred'],
#        ['-0.2429025638159412', '0.0318028849216246',
#         '0.19681138556836109', 'unbarred'],
#        ['-1.1696954560465576', '0.02705088915391247',
#         '0.1960995884850788', 'barred'],
#        ['-1.449291512642506', '0.0120407858668806',
#         '0.19459773514687181', 'unbarred'],
#        ['-1.3072152264080332', '0.02979782600729676',
#         '0.19649734968889815', 'barred'],
#        ['-2.1627672043286443', '0.017644634705545992',
#         '0.1950246936515788', 'unbarred'],
#        ['-1.4739236317410753', '0.017205288390499833',
#         '0.19498543522171152', 'unbarred'],
#        ['-1.189328682008253', '0.019017115613497077',
#         '0.1951536540428006', 'barred'],
#        ['-1.6291110145242853', '0.019879366996199993',
#         '0.19523956369591078', 'barred'],
#        ['-2.1737805467550215', '0.017001482405390598',
#         '0.19496755731141732', 'unbarred'],
#        ['-1.353742332494334', '0.025385595225656133',
#         '0.1958768144650123', 'unbarred'],
#        ['-1.2787627498186342', '0.014173585120134656',
#         '0.194741337458583', 'barred'],
#        ['-0.5544328733153506', '0.04024020403436829',
#         '0.19834962067200326', 'barred'],
#        ['-1.368601994112577', '0.02178221279688463',
#         '0.19544247950312327', 'unbarred'],
#        ['-1.9085166910867253', '0.019246113508538214',
#         '0.19517610223893583', 'unbarred'],
#        ['-0.7125480983311271', '0.027253865256465906',
#         '0.19612769098579017', 'unbarred'],
#        ['-2.2785810333562293', '0.032966626758189954',
#         '0.19700278292403334', 'unbarred'],
#        ['-2.2884809482265025', '0.016734317444070942',
#         '0.19494444177846912', 'barred'],
#        ['-1.959371802231508', '0.014272960291230413',
#         '0.19474859536200778', 'barred'],
#        ['-1.2269357983010958', '0.02831440941062608',
#         '0.19627787389380533', 'barred'],
#        ['-2.2390299302838175', '0.012492533445741638',
#         '0.19462620941664813', 'unbarred'],
#        ['-1.690079567202026', '0.02387701532023962',
#         '0.19568702016383957', 'barred'],
#        ['-0.878453753621759', '0.029746351720343626',
#         '0.1964895504617749', 'barred'],
#        ['-0.5578140062427126', '0.034321820686085865',
#         '0.19723408776174525', 'unbarred'],
#        ['-0.3272948642413445', '0.023159431258730934',
#         '0.19560075985595732', 'barred'],
#        ['-1.4263611762444124', '0.019709002499747538',
#         '0.1952222906830443', 'unbarred'],
#        ['-1.0455823748892863', '0.014144865626641953',
#         '0.19473924931455333', 'barred'],
#        ['-2.295827475945364', '0.020360000490021627',
#         '0.19528908730380629', 'barred'],
#        ['-0.21896054871812576', '0.036130187799331186',
#         '0.19755679808706897', 'barred'],
#        ['-2.076703534519468', '0.012831967343231658',
#         '0.1946482915052114', 'barred'],
#        ['-0.9816156935846962', '0.019491549417493842',
#         '0.19520045721948143', 'barred'],
#        ['-1.9480105983860165', '0.01944239634977846',
#         '0.19519555521533238', 'barred'],
#        ['-1.7412844682191808', '0.02262420616056888',
#         '0.1955381106188661', 'unbarred'],
#        ['-1.2768466006527377', '0.018358935321849363',
#         '0.19509061614068435', 'barred'],
#        ['-1.7409565908750437', '0.016531409611869562',
#         '0.19492712870135703', 'unbarred'],
#        ['-0.1482057318677955', '0.016412244974691792',
#         '0.19491705873296283', 'barred'],
#        ['-1.1344684323671275', '0.021079008522514996',
#         '0.19536535670454028', 'barred'],
#        ['-0.6559102078653052', '0.07573706672782021',
#         '0.20846918543644355', 'unbarred'],
#        ['-1.4037428488269597', '0.02554213527812158',
#         '0.19589716351842837', 'barred'],
#        ['-2.1998448006418787', '0.017547231218117524',
#         '0.19501590530882879', 'barred'],
#        ['-1.6550000260432796', '0.01659560993422418',
#         '0.1949325839081012', 'barred'],
#        ['-1.8359134978233231', '0.02851929689755611',
#         '0.19630753499428122', 'unbarred'],
#        ['-0.9692722041229707', '0.01714218803849064',
#         '0.1949798774508461', 'unbarred'],
#        ['-1.0319639159766902', '0.0218765622664752',
#         '0.1954530173125986', 'barred'],
#        ['-1.5451019199114489', '0.022319469024908653',
#         '0.19550308615864315', 'unbarred'],
#        ['-1.3446409939575252', '0.029497085669249815',
#         '0.1964519688447511', 'unbarred'],
#        ['-1.2498743017896679', '0.03291596289531418',
#         '0.19699431111919372', 'unbarred'],
#        ['-0.4722585085511167', '0.027448007333063254',
#         '0.19615476315031427', 'unbarred'],
#        ['-2.106377394662021', '0.018274473986762928',
#         '0.1950826860577147', 'unbarred'],
#        ['-1.1225476185984489', '0.03925904644960217',
#         '0.19815289734982938', 'barred'],
#        ['-1.5475007934723264', '0.03095388869589465',
#         '0.19667598029601335', 'barred'],
#        ['-1.485855673503693', '0.020752674930690548',
#         '0.19533041626121342', 'unbarred'],
#        ['-1.8249470116127564', '0.02212393731216445',
#         '0.19548085993823686', 'barred'],
#        ['-1.1394652178670708', '0.01171307418015348',
#         '0.19457773281326352', 'unbarred'],
#        ['-1.997353338376736', '0.016947917420905203',
#         '0.19496289366160377', 'unbarred'],
#        ['-1.636597888536613', '0.018337908260232523',
#         '0.19508863851941943', 'unbarred'],
#        ['-0.7291377896340692', '0.022562771235782722',
#         '0.19553101197978354', 'barred'],
#        ['0.37918070743410676', '0.037234296633818276',
#         '0.19776170217161654', 'unbarred'],
#        ['-0.8283994638054081', '0.021136091815419235',
#         '0.1953715239671069', 'barred'],
#        ['-2.0941587558124772', '0.01769099770815508',
#         '0.1950288937565661', 'barred'],
#        ['-2.3038254151897974', '0.015731679306900177',
#         '0.19486093434502244', 'unbarred'],
#        ['-2.334218621393373', '0.016796077803364094',
#         '0.1949497530892939', 'barred'],
#        ['-1.6768466297041753', '0.024912543364269176',
#         '0.19581606884236183', 'unbarred'],
#        ['-0.050839301046269374', '0.04340235057275653',
#         '0.1990152306614759', 'unbarred'],
#        ['-1.967357256454909', '0.015334941852237821',
#         '0.19482930591061373', 'unbarred'],
#        ['-0.8366166951085621', '0.012941654754893388',
#         '0.1946555532929766', 'unbarred'],
#        ['-1.683122325207559', '0.019110894972721143',
#         '0.1951628148666092', 'barred'],
#        ['-1.5610238677203343', '0.019343326349926714',
#         '0.19518571226982717', 'barred'],
#        ['-1.0444654959258566', '0.02874765287787079',
#         '0.19634084023958578', 'barred'],
#        ['-0.9685080286711136', '0.02566494669086377',
#         '0.19591321417567747', 'unbarred'],
#        ['-2.2555609291108714', '0.01609473886651284',
#         '0.19489058114537303', 'barred'],
#        ['-1.2030604528067916', '0.02368700195924053',
#         '0.19566392631708346', 'barred'],
#        ['-1.9179052437444155', '0.018114194239679603',
#         '0.19506773703755534', 'barred'],
#        ['-1.8274598984650714', '0.015660122061913598',
#         '0.19485517037788355', 'unbarred'],
#        ['-1.9065545568671853', '0.01961360772197597',
#         '0.19521268300976644', 'barred'],
#        ['-1.67320799583496', '0.018013775573071725',
#         '0.19505843768060122', 'unbarred'],
#        ['-2.4312523101951586', '0.016568091748800202',
#         '0.1949302430722248', 'unbarred'],
#        ['-1.6914984737004075', '0.018230433302375306',
#         '0.1950785654509289', 'unbarred'],
#        ['-1.162154437501603', '0.023170736110123814',
#         '0.19560209868987855', 'barred'],
#        ['-1.7114935262097115', '0.015591665274388915',
#         '0.19484968059000912', 'barred'],
#        ['-1.1966834721825168', '0.023703460260731026',
#         '0.1956659194349697', 'barred'],
#        ['-1.7129598634604086', '0.01627731627692583',
#         '0.19490574395122137', 'unbarred'],
#        ['-0.8784713817816868', '0.02780797256755461',
#         '0.19620545695346464', 'barred'],
#        ['-1.1912393648702442', '0.024581003605398288',
#         '0.1957741651450686', 'unbarred'],
#        ['-1.3800328824713601', '0.022386478549067765',
#         '0.19551074758648912', 'barred'],
#        ['0.6897804741972772', '0.024082153669379543',
#         '0.19571215630449634', 'unbarred'],
#        ['-2.3297224835829504', '0.021996641532037127',
#         '0.19546649390289103', 'unbarred'],
#        ['-1.7161260385757129', '0.01558145112820781',
#         '0.1948488635308421', 'barred'],
#        ['-2.1375362903179527', '0.016155711513842593',
#         '0.19489562595019547', 'unbarred'],
#        ['-1.653966310255051', '0.015538675236257467',
#         '0.1948454475426559', 'barred'],
#        ['-1.4513561535836028', '0.01790959646968967',
#         '0.19504884425627114', 'unbarred'],
#        ['-1.976094145400736', '0.026034799264983626',
#         '0.19596200849340156', 'unbarred'],
#        ['-1.0969010618425965', '0.016056875720885096',
#         '0.19488745792871318', 'unbarred'],
#        ['-1.9390118692901848', '0.012526284200043154',
#         '0.19462837870120647', 'unbarred'],
#        ['-1.6912605853651348', '0.02231586180587136',
#         '0.19550267437592445', 'barred'],
#        ['-1.8177181351803293', '0.01766473368298329',
#         '0.19502651311062996', 'unbarred'],
#        ['-1.4835877192533364', '0.017477440664441016',
#         '0.19500963804945398', 'unbarred'],
#        ['-2.4756531231557344', '0.012871618201690197',
#         '0.19465090946391717', 'barred'],
#        ['-1.6461309176884977', '0.02108660219760646',
#         '0.19536617617243804', 'barred'],
#        ['-1.661947015746238', '0.018074517766245832',
#         '0.19506405663904955', 'unbarred'],
#        ['-1.9017813029497266', '0.015613412641379575',
#         '0.19485142199714628', 'barred'],
#        ['-1.41953510117701', '0.019788224500374173',
#         '0.1952303045863454', 'barred'],
#        ['-1.6430367700504735', '0.020685205304965315',
#         '0.19532325954301644', 'unbarred'],
#        ['-1.8615018286952767', '0.014631796189518055',
#         '0.19477522291023464', 'barred'],
#        ['0.1277816169726553', '0.03270499754115867',
#         '0.19695917055107434', 'barred'],
#        ['-1.819372414855628', '0.015743184031159915',
#         '0.19486186349165135', 'unbarred'],
#        ['-1.0206392563262323', '0.013518682739594938',
#         '0.1946947682476697', 'unbarred'],
#        ['-1.1941851899919327', '0.023079412442298313',
#         '0.19559130164371244', 'barred'],
#        ['-2.0239953757707796', '0.014722944093142428',
#         '0.19478209127835597', 'unbarred'],
#        ['-1.0987234694127963', '0.03311593498433767',
#         '0.19702782328870933', 'barred'],
#        ['-2.4065868257786684', '0.018891301292753807',
#         '0.19514143400245268', 'unbarred'],
#        ['-1.4616063846546792', '0.01694931918929015',
#         '0.1949630155208429', 'unbarred'],
#        ['-0.25382350485998484', '0.01789366447240343',
#         '0.19504738200819552', 'unbarred'],
#        ['-0.725179627404749', '0.014386687619892728',
#         '0.1947569633688931', 'barred'],
#        ['-1.482877452154652', '0.028909399323050332',
#         '0.1963645878696553', 'barred'],
#        ['-2.0017542204843175', '0.01939828728807246',
#         '0.195191166679516', 'unbarred'],
#        ['-0.7273946345320773', '0.01758043817264572',
#         '0.19501889602380126', 'barred'],
#        ['-1.494164176930706', '0.015457712252901249',
#         '0.19483900756289405', 'unbarred'],
#        ['-1.651597249721874', '0.022304242808912775',
#         '0.19550134845386344', 'barred'],
#        ['-2.83282159122021', '0.01647370710242721', '0.1949222435375105',
#         'unbarred'],
#        ['-0.9470756657979476', '0.01499795389850553',
#         '0.1948030713852882', 'unbarred'],
#        ['-0.43590779561896686', '0.025884484803689985',
#         '0.19594209489936676', 'unbarred'],
#        ['-0.9846765512753823', '0.011136055989790583',
#         '0.1945438504373956', 'unbarred'],
#        ['-1.9697237034146977', '0.028818221079821415',
#         '0.19635118503896395', 'barred'],
#        ['-2.151302475635534', '0.012071145068344395',
#         '0.19459961598950037', 'barred'],
#        ['-0.045395489068239606', '0.022354164741050356',
#         '0.19550705020860504', 'barred'],
#        ['-1.624957611141259', '0.022416158746019096',
#         '0.19551414826791108', 'barred'],
#        ['-1.8136139187454505', '0.02326210135099488',
#         '0.19561294271919727', 'barred'],
#        ['-1.174469782582741', '0.029102724237933912',
#         '0.196393142848902', 'unbarred'],
#        ['-2.106928975157115', '0.020067068864752086',
#         '0.19525876485531374', 'unbarred'],
#        ['-0.8279209528176776', '0.03254103953816489',
#         '0.1969320117558961', 'unbarred'],
#        ['-1.2338452718935005', '0.019214497378192093',
#         '0.19517298714088624', 'barred'],
#        ['-1.8267510446905382', '0.017985865927985314',
#         '0.1950558621861426', 'unbarred'],
#        ['-1.8837212749163712', '0.02197472342793139',
#         '0.19546402858258619', 'barred'],
#        ['-1.8006584757448492', '0.02257690684450886',
#         '0.1955326436241929', 'unbarred'],
#        ['-2.273598605880174', '0.02041146196295444',
#         '0.19529445916222285', 'barred'],
#        ['-2.141073786053663', '0.018124987991294646',
#         '0.19506873965267876', 'unbarred'],
#        ['-1.9520368090833733', '0.019152955092083687',
#         '0.1951669380011875', 'barred'],
#        ['-1.2608659930004789', '0.022768879447877782',
#         '0.19555490244765533', 'unbarred'],
#        ['-1.7992174494648518', '0.020686376749307074',
#         '0.1953233836052772', 'barred'],
#        ['-1.3440962621799504', '0.03398201906489101',
#         '0.19717524088923186', 'barred'],
#        ['-1.058191661093136', '0.022773599031109478',
#         '0.19555545201509916', 'unbarred']], dtype='<U32')

# %%
dens = dens[dens[:, 0] != '-999']

# %%
np.save('./STRM_dens_nn.npy', dens)

# %%
plt.figure(figsize=(8, 5))
plt.hist(dens[:,0][dens[:,-1] == 'barred'].astype(np.float64), bins=20, label='Density Distribution', color='orange', alpha=0.7, cumulative=False)
plt.hist(dens[:,0][dens[:,-1] == 'unbarred'].astype(np.float64), bins=20, label='Density Distribution', color='blue', alpha=0.7, cumulative=False)
plt.xlabel('Density (5th Nearest Neighbor)')
plt.ylabel('Frequency')
plt.title('Histogram of Density Distribution')
plt.legend()
plt.tight_layout()
plt.savefig('../fig/density_distribution_histogram_STRM.png', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. 直接提取您的數據並轉為 float
b_dens = dens[:, 0][dens[:, -1] == 'barred'].astype(float)
ub_dens = dens[:, 0][dens[:, -1] == 'unbarred'].astype(float)

# 2. 完全交給算法自動決定最優分箱邊界 (bins='auto')，絕不人工限制
all_data = np.concatenate([b_dens, ub_dens])
bins = np.histogram_bin_edges(all_data, bins='auto')
bin_centers = 0.5 * (bins[:-1] + bins[1:])
bin_width = np.diff(bins)  # 自動適應每個 bin 的實際寬度

# 3. 創建畫布
plt.figure(figsize=(8, 6))

# 4. 繪製標準的 overlapping plt.hist 並獲取每個 bin 的歸一化高度 (density=True)
b_heights, _, _ = plt.hist(b_dens, bins=bins, alpha=0.5, color='#0173b2', 
                           label='Barred NLS1', edgecolor='black', density=True)

ub_heights, _, _ = plt.hist(ub_dens, bins=bins, alpha=0.5, color='#de8f05', 
                            label='Unbarred NLS1', edgecolor='black', density=True)

# 5. 【拒絕任何 MC】直接解析計算每個 bin 的歸一化泊松誤差（Y 軸誤差棒）
# 獲取每個 bin 的原始星系計數 N
counts_b, _ = np.histogram(b_dens, bins=bins)
counts_ub, _ = np.histogram(ub_dens, bins=bins)

# 歸一化直方圖的泊松誤差公式： \sigma = \sqrt{N} / (N_total * bin_width)
b_bin_errs = np.sqrt(counts_b) / (len(b_dens) * bin_width)
ub_bin_errs = np.sqrt(counts_ub) / (len(ub_dens) * bin_width)

# 6. 在每個自動生成的柱子正上方繪製垂直誤差棒
# 左右微調 10% 的 bin 寬度，防止藍色和橙色的誤差棒完全重疊在一起
plt.errorbar(bin_centers - bin_width * 0.1, b_heights, yerr=b_bin_errs, 
             fmt='none', ecolor='#0173b2', elinewidth=1.5, capsize=3)

plt.errorbar(bin_centers + bin_width * 0.1, ub_heights, yerr=ub_bin_errs, 
             fmt='none', ecolor='#de8f05', elinewidth=1.5, capsize=3)

# 標籤與樣式 (使用 raw string 避免任何 SyntaxWarning)
plt.xlabel(r'$\log_{10}(\Sigma_5 \ [\mathrm{Mpc}^{-2}])$', fontsize=12)
plt.ylabel('Density (Normalized)', fontsize=12)
plt.title('Environmental Density Distribution with Poisson Error Bars', fontsize=14, fontweight='bold')
plt.legend(fontsize=11, loc='upper left')
plt.grid(True, linestyle=':', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
# index_arr[index_arr != -999].size

# %%
# dens = []
# for i, idx in enumerate(index_arr):
#     if idx == -999:
#         continue
#     idx = int(idx)
#     file_list = glob.glob(f'../data/catalog/ps1/redshift_STRM/t{tg_ra[i]:08.4f}{tg_dec[i]:+07.4f}.csv')
#     if len(file_list) == 0:
#         continue
#     df = pd.read_csv(file_list[0])
#     if idx >= len(df):
#         continue
#     row = df.distance_arcmin.iloc[idx] / 60
#     row = np.deg2rad(row)
#     fifth_dis = row * tg_d[i]
#     if fifth_dis <= 0 or not np.isfinite(fifth_dis):
#         continue
#     fifth_dens = 5 / np.pi / fifth_dis**2
#     fifth_dens = np.log(fifth_dens)
#     dens.append(fifth_dens)

# %%
# plt.hist(dens, bins = 50, label = 'Density Distribution', color = 'blue', alpha = 0.7)
# plt.xlabel('Density (5th Nearest Neighbor)')
# plt.ylabel('Frequency')
# plt.title('Histogram of Density Distribution')
# plt.legend()
# plt.savefig('../fig/density_distribution_histogram_STRM.png', dpi=300)
# plt.show()

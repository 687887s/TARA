# %%
from sklearn.neighbors import NearestNeighbors
import glob
import pandas as pd
from astropy.cosmology import Planck18, z_at_value
from astropy import units as u
import numpy as np
from astropy.coordinates import SkyCoord
from scipy.stats import norm
from joblib import Parallel, delayed
import matplotlib.pyplot as plt

# %%
barred_target = pd.read_csv('../data/matched_barred_ps1_resolved.csv')
unbarred_target = pd.read_csv('../data/matched_unbarred_ps1_resolved.csv')

# %%
model = ['llr', 'llr_filtered', 'xgb', 'xgb_filtered']
col = {'llr':'', 'llr_filtered':'_llr_filtered', 'xgb':'_xgb_origin', 'xgb_filtered':'_xgb_filtered'}

# %%
target = pd.read_csv('../all_sample_20260702.csv')
target = pd.merge(target, barred_target[['paliya_RA', 'class']], how='left', on='paliya_RA')
target = pd.merge(target, unbarred_target[['paliya_RA', 'class']], how='left', on='paliya_RA')
target['class'] = target['class_x'].combine_first(target['class_y'])
target = target.drop(['class_x', 'class_y'], axis=1)

target = target[target['class'].isin(['barred', 'unbarred'])]
tg_z = (target.paliya_Z).values
tg_d = Planck18.comoving_distance(target.paliya_Z).value
tg_ra = (target.paliya_RA).values
tg_dec = (target.paliya_DEC).values

coord = SkyCoord(ra = tg_ra * u.deg, dec = tg_dec * u.deg, distance = tg_d * u.Mpc)
tg_df = pd.DataFrame({'coord':coord})

# %%
dens_df = pd.DataFrame()
dens_df['class'] = [target['class'].values]
for m in [model[0], model[2]]:
    def compute_index_for_i(i):
        file_list = glob.glob(f'../data/catalog/ps1/merged/t{tg_ra[i]:08.4f}{tg_dec[i]:+07.4f}.csv')
        if len(file_list) == 0:
            return [-999]*3

        target_z = float(target.paliya_Z.iloc[i])
        df = pd.read_csv(file_list[0])
        # df = df[df.Absolute_Mag_r < -20.5]

        z_window = (
            z_at_value(Planck18.comoving_distance, (tg_d[i] + 5) * u.Mpc)
            - z_at_value(Planck18.comoving_distance, (tg_d[i] - 5) * u.Mpc)
        )
        # df = df[np.isfinite(df.z_phot0) & np.isfinite(df.z_photErr)]
        # df = df[np.abs(df.z_phot0 - target_z) < z_window]

        if len(df) == 0:
            return [-999]*3

        surround_z = df[f'z_phot{col[m]}'].to_numpy(dtype=float)
        surround_err = df[f'z_phot_err{col[m]}'].to_numpy(dtype=float)
        surround_ra = df.raMean.to_numpy(dtype=float)
        surround_dec = df.decMean.to_numpy(dtype=float)

        mask = (surround_z - surround_err / 2) > -1
        surround_z = surround_z[mask]
        surround_err = surround_err[mask]
        surround_ra = surround_ra[mask]
        surround_dec = surround_dec[mask]

        if len(surround_z) == 0:
            return [-999]*3

        surround_d = Planck18.comoving_distance(surround_z).value
        valid = np.isfinite(surround_d) & (surround_d >= 0)
        surround_z = surround_z[valid]
        surround_err = surround_err[valid]
        surround_ra = surround_ra[valid]
        surround_dec = surround_dec[valid]
        surround_d = surround_d[valid]

        if len(surround_d) == 0:
            return [-999]*3

        z_low = surround_z - surround_err / 2
        id = np.where(z_low < 0)
        z_low[id] = abs(surround_z[id] - surround_err[id] /2)
        z_low = Planck18.comoving_distance(z_low)
        z_low[id] = z_low[id] * -1
        surround_scale = (
            Planck18.comoving_distance(surround_z + surround_err / 2)
            - z_low
        ).value
        surround_odds = np.abs(
            norm.cdf(Planck18.comoving_distance(tg_z[i] + 1000/300000), loc=surround_d, scale=surround_scale)
            - norm.cdf(Planck18.comoving_distance(tg_z[i] - 1000/300000), loc=surround_d, scale=surround_scale)
        )

        coord_1 = SkyCoord(ra=surround_ra * u.deg, dec=surround_dec * u.deg, distance=surround_d * u.Mpc)
        target_coord = coord[i]

        df_surround = target_coord.separation(coord_1)
        df_surround = df_surround.to_value(u.rad) * tg_d[i]
        X = np.asarray(df_surround, dtype=float).reshape(-1, 1)
        nn = NearestNeighbors(n_neighbors=max(1, min(int(len(X) / 2), len(X))), algorithm='auto')
        nn.fit(X)
        neighbors = nn.kneighbors(np.array([[0]]))
        k_index = np.where(np.cumsum(surround_odds[neighbors[1][0]]) >= 5)[0]
        if len(k_index) == 0:
            return [-999]*3

        index = neighbors[1][0][:k_index[0]]
            
        row = df.distance.iloc[index] / 60
        row = np.deg2rad(row)
        fifth_dis = row * tg_d[i]
        fifth_dis = (fifth_dis**2) * surround_odds[index]
        fifth_dens = np.sum(surround_odds[index]) / np.pi / np.sum(fifth_dis)
        fifth_dens = np.log(fifth_dens)
        from mc_density_error import calculate_single_target_5nn_error
        error, error_total = calculate_single_target_5nn_error(tg_z[i], df.z_phot.iloc[index], df.z_phot_err.iloc[index], df.distance.iloc[index], n_mc_realizations = 10000)
        return [fifth_dens, error, error_total]
        

    dens = Parallel(n_jobs=-1, verbose=51)(delayed(compute_index_for_i)(i) for i in range(len(tg_df)))
    dens_df[f'dens_{m}'] = [dens]
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    7.2s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:    9.2s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   23.2s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   29.2s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   33.4s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   34.6s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   37.1s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:   38.5s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:   38.8s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   39.1s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   40.1s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:   44.6s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:   45.5s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   47.3s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:   47.7s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:   53.5s
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:   56.9s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   57.3s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:   59.2s
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:   59.9s
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 187 out of 202 | elapsed:  1.7min remaining:    8.4s
# [Parallel(n_jobs=-1)]: Done 191 out of 202 | elapsed:  1.8min remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done 195 out of 202 | elapsed:  1.8min remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done 199 out of 202 | elapsed:  1.9min remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 202 out of 202 | elapsed:  1.9min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    8.8s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   15.9s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   19.0s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   20.0s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:   21.3s
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   23.9s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   28.0s
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   32.5s
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:   32.6s
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:   38.0s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   38.1s
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:   38.6s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:   40.3s
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:   40.6s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   41.3s
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:   41.5s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:   41.5s
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:   42.1s
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   43.1s
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:   43.3s
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:   43.9s
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:   45.3s
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   45.5s
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:   45.8s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:   46.3s
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:   46.9s
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:   48.2s
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:   48.3s
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:   48.7s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:   49.4s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:   51.5s
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:   51.9s
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   54.9s
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:   54.9s
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:   55.6s
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:   56.0s
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:   56.7s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   57.2s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:   57.3s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:   57.5s
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:   58.2s
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:   58.8s
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   59.7s
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:   59.8s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:   59.8s
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 187 out of 202 | elapsed:  1.3min remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done 191 out of 202 | elapsed:  1.3min remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done 195 out of 202 | elapsed:  1.4min remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 199 out of 202 | elapsed:  1.4min remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 202 out of 202 | elapsed:  1.4min finished

# %%
dens_df
# Out:
#                                                class  \
# 0  [barred, barred, barred, unbarred, barred, bar...
#
#                                             dens_llr  \
# 0  [[-1.534596807569611, 0.01571186595708725, 0.1...
#
#                                             dens_xgb
# 0  [[-1.5443981524784005, 0.01566353346056579, 0....

# %%
c = dens_df['class'][0]
llr_dens = np.array(dens_df.dens_llr[0])
llr_dens = np.array([[llr_dens[i][0], llr_dens[i][1], llr_dens[i][2], j] for i, j in enumerate(c)])
llr_dens = llr_dens[llr_dens[:,0] != '-999.0']
xgb_dens = np.array(dens_df.dens_xgb[0])
xgb_dens = np.array([[xgb_dens[i][0], xgb_dens[i][1], xgb_dens[i][2], j] for i ,j in enumerate(c)])
xgb_dens = xgb_dens[xgb_dens[:,0] != '-999.0']
# llr_dens = np.array([dens_df.dens_llr[0][dens_df.dens_llr[0] != -999], c[dens_df.dens_llr[0] != -999]])
# llr_filtered_dens = np.array([dens_df.dens_llr_filtered[0][dens_df.dens_llr_filtered[0] != -999], c[dens_df.dens_llr_filtered[0] != -999]])
# xgb_dens = np.array([dens_df.dens_xgb[0][dens_df.dens_xgb[0] != -999], c[dens_df.dens_xgb[0] != -999]])
# xgb_filtered_dens = np.array([dens_df.dens_xgb_filtered[0][dens_df.dens_xgb_filtered[0] != -999], c[dens_df.dens_xgb_filtered[0] != -999]])

# %%
np.save('./llr_dens_nn.npy', llr_dens)
np.save('./xgb_dens_nn.npy', xgb_dens)

# %%
# dens = []
# for i, idx in enumerate(llr_arr):
#     if idx == -999:
#         continue
#     idx = int(idx)
#     file_list = glob.glob(f'../data/catalog/ps1/merged/t{tg_ra[i]:08.4f}{tg_dec[i]:+07.4f}.csv')
#     if len(file_list) == 0:
#         continue
#     df = pd.read_csv(file_list[0])
#     if idx >= len(df):
#         continue
#     row = df.distance.iloc[idx] / 60
#     row = np.deg2rad(row)
#     fifth_dis = row * tg_d[i]
#     if fifth_dis <= 0 or not np.isfinite(fifth_dis):
#         continue
#     fifth_dens = 5 / np.pi / fifth_dis**2
#     fifth_dens = np.log(fifth_dens)
#     dens.append(fifth_dens)

# %%
plt.figure(figsize=(8, 5))
plt.hist(llr_dens[:, 0][llr_dens[:, -1] == 'barred'].astype(np.float64), bins=20, label='Barred Galaxies', color='blue', alpha=0.7)
plt.hist(llr_dens[:, 0][llr_dens[:, -1] == 'unbarred'].astype(np.float64), bins=20, label='Unbarred Galaxies', color='orange', alpha=0.7)
plt.xlabel('Density (5th nearest neighbor)')
plt.ylabel('Frequency')
plt.title('Histogram of LLR Density Values')
plt.legend()
plt.tight_layout()
plt.savefig(f'../fig/llr_density_histogram.png', dpi=300)
plt.show()

# %%
# dens = []
# for i, idx in enumerate(xgb_arr):
#     if idx == -999:
#         continue
#     idx = int(idx)
#     file_list = glob.glob(f'../data/catalog/ps1/merged/t{tg_ra[i]:08.4f}{tg_dec[i]:+07.4f}.csv')
#     if len(file_list) == 0:
#         continue
#     df = pd.read_csv(file_list[0])
#     if idx >= len(df):
#         continue
#     row = df.distance.iloc[idx] / 60
#     row = np.deg2rad(row)
#     fifth_dis = row * tg_d[i]
#     if fifth_dis <= 0 or not np.isfinite(fifth_dis):
#         continue
#     fifth_dens = 5 / np.pi / fifth_dis**2
#     fifth_dens = np.log(fifth_dens)
#     dens.append(fifth_dens)

# %%
plt.figure(figsize=(8, 5))
plt.hist(xgb_dens[:, 0][xgb_dens[:, -1] == 'barred'].astype(np.float64), bins=20, label='XGB density distribution', color='green', alpha=0.7)
plt.hist(xgb_dens[:, 0][xgb_dens[:, -1] == 'unbarred'].astype(np.float64), bins=20, label='XGB density distribution', color='red', alpha=0.7)
plt.xlabel('Density (5th nearest neighbor)')
plt.ylabel('Frequency')
plt.title('Histogram of XGB Density Values')
plt.legend()
plt.tight_layout()
plt.savefig(f'../fig/xgb_density_histogram.png', dpi=300)
plt.show()

# %%
# dens = []
# for i, idx in enumerate(llr_filtered_arr):
#     if idx == -999:
#         continue
#     idx = int(idx)
#     file_list = glob.glob(f'../data/catalog/ps1/merged/t{tg_ra[i]:08.4f}{tg_dec[i]:+07.4f}.csv')
#     if len(file_list) == 0:
#         continue
#     df = pd.read_csv(file_list[0])
#     if idx >= len(df):
#         continue
#     row = df.distance.iloc[idx] / 60
#     row = np.deg2rad(row)
#     fifth_dis = row * tg_d[i]
#     if fifth_dis <= 0 or not np.isfinite(fifth_dis):
#         continue
#     fifth_dens = 5 / np.pi / fifth_dis**2
#     fifth_dens = np.log(fifth_dens)
#     dens.append(fifth_dens)

# %%
# plt.figure(figsize=(8, 5))
# plt.hist(llr_filtered_dens, bins=10, label='LLR filtered density distribution', color='orange', alpha=0.7)
# plt.xlabel('Density (5th nearest neighbor)')
# plt.ylabel('Frequency')
# plt.title('Histogram of LLR Filtered Density Values')
# plt.legend()
# plt.tight_layout()
# plt.savefig(f'../fig/llr_filtered_density_histogram_{len(glob.glob("../fig/*.png"))}.png', dpi=300)
# plt.show()

# %%
# dens = []
# for i, idx in enumerate(xgb_filtered_arr):
#     if idx == -999:
#         continue
#     idx = int(idx)
#     file_list = glob.glob(f'../data/catalog/ps1/merged/t{tg_ra[i]:08.4f}{tg_dec[i]:+07.4f}.csv')
#     if len(file_list) == 0:
#         continue
#     df = pd.read_csv(file_list[0])
#     if idx >= len(df):
#         continue
#     row = df.distance.iloc[idx] / 60
#     row = np.deg2rad(row)
#     fifth_dis = row * tg_d[i]
#     if fifth_dis <= 0 or not np.isfinite(fifth_dis):
#         continue
#     fifth_dens = 5 / np.pi / fifth_dis**2
#     fifth_dens = np.log(fifth_dens)
#     dens.append(fifth_dens)

# %%
# plt.figure(figsize=(8, 5))
# plt.hist(xgb_filtered_dens, bins=10, label='XGB filtered density distribution', color='purple', alpha=0.7)
# plt.xlabel('Density (5th nearest neighbor)')
# plt.ylabel('Frequency')
# plt.title('Histogram of XGB Filtered Density Values')
# plt.legend()
# plt.tight_layout()
# plt.savefig(f'../fig/xgb_filtered_density_histogram_{len(glob.glob("../fig/*.png"))}.png', dpi=300)
# plt.show()
